# %% [markdown]
# <a href="https://colab.research.google.com/github/asheldrick-research/ecsm-framework/blob/main/ECSM_NG9R_EXECUTED_CMB_and_Cosmological_Propagation_from_Frequency_Dependent_Response_Kernel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ECSM NG9R — CMB and Cosmological Propagation from a Frequency-Dependent Response Kernel
#
# This evidence notebook rebuilds CMB-like propagation without physical FLRW curvature, metric perturbations, geodesics or scale-factor ontology.
#
# Main result:
# - acoustic-like peaks arise from a finite-response propagation kernel;
# - damping tail is response/coherence suppression;
# - TT/EE/TE-like branches share one phase-locked kernel;
# - domain-boundary transfer is explicit;
# - omitting the boundary term leaves a localized residual;
# - no physical metric or curvature equation appears.
#
# Tests passed: 33/33.

# %% [markdown]
# ## Metadata
#
# ```json
# {
#   "notebook": "ECSM NG9R",
#   "title": "CMB and Cosmological Propagation from the Same Frequency-Dependent Response Kernel",
#   "physical_metric": false,
#   "curvature_action": false,
#   "einstein_equations": false,
#   "geodesic_equation": false,
#   "FLRW_geometry": false,
#   "scale_factor_ontology": false,
#   "frequency_dependent_response_kernel": true,
#   "domain_boundary_transfer_included": true,
#   "peaks_found": 5,
#   "first_peak_ell": 212.0,
#   "mean_peak_spacing": 219.5,
#   "spacing_relative_error": 0.0018711426093991803,
#   "damping_tail_ratio": 0.1886542441106371,
#   "delta_chi2_omitting_boundary": 342.8346377595549,
#   "TE_phase_correlation": 1.0,
#   "parameter_scan_points": 50000,
#   "parameter_scan_all_conditions": 50000,
#   "main_result": "CMB-like acoustic, damping and polarisation structures can be represented as finite-response propagation through a frequency-dependent medium kernel with explicit domain-boundary transfer.",
#   "claim_boundary": "Synthetic benchmark only; not a Planck/ACT/SPT likelihood fit.",
#   "next_notebook": "NG10R - End-to-End Non-Geometric Audit and Publication Spine"
# }
# ```

# %% [markdown]
# ## Test summary
#
# | test                                                       | passed   | detail   |
# |:-----------------------------------------------------------|:---------|:---------|
# | CMB transfer profile exported                              | True     |          |
# | CMB transfer finite                                        | True     |          |
# | TT positive                                                | True     |          |
# | EE positive                                                | True     |          |
# | Peak table exported                                        | True     |          |
# | At least four acoustic peaks found                         | True     |          |
# | Peak spacing recovered                                     | True     |          |
# | Damping tail suppressed                                    | True     |          |
# | Boundary omission CMB test exported                        | True     |          |
# | Omitting boundary worsens chi2                             | True     |          |
# | Boundary omitted residual larger than same-kernel residual | True     |          |
# | Boundary peak at configured scale                          | True     |          |
# | TT/EE/TE shared kernel table exported                      | True     |          |
# | TT/EE/TE all finite                                        | True     |          |
# | TE phase correlation closes                                | True     |          |
# | TE has sign changes                                        | True     |          |
# | Parameter scan exported                                    | True     |          |
# | Parameter scan has 50,000 rows                             | True     |          |
# | More than 45,000 parameter samples pass                    | True     |          |
# | Comparison table exported                                  | True     |          |
# | Failure mode table exported                                | True     |          |
# | Claim ledger exported                                      | True     |          |
# | Ontology audit exported                                    | True     |          |
# | No forbidden geometric primitive present                   | True     |          |
# | Metadata exported                                          | True     |          |
# | Six paper figures exported                                 | True     |          |
# | No physical metric in metadata                             | True     |          |
# | No curvature action in metadata                            | True     |          |
# | No Einstein equations in metadata                          | True     |          |
# | No geodesic equation in metadata                           | True     |          |
# | No FLRW geometry in metadata                               | True     |          |
# | No scale-factor ontology in metadata                       | True     |          |
# | Boundary transfer included                                 | True     |          |

# %% [markdown]
# ## Non-geometric comparison
#
# | aspect             | standard_geometric_language            | non_geometric_NG9R_language                                  | assessment                      |
# |:-------------------|:---------------------------------------|:-------------------------------------------------------------|:--------------------------------|
# | Acoustic structure | metric-expansion acoustic horizon      | finite-response propagation horizon                          | NG9R better ontology            |
# | Peak spacing       | angular-diameter geometry              | response lever arm D_eff and response scale s_resp           | NG9R non-geometric dictionary   |
# | Damping tail       | photon diffusion in metric background  | finite-response coherence/diffusion suppression              | NG9R better ontology            |
# | TT/EE/TE relation  | Boltzmann hierarchy on FLRW            | shared response kernel with phase-locked polarisation branch | benchmark only                  |
# | Boundary features  | secondary geometric/lensing correction | explicit domain-boundary transfer                            | NG9R better ontology            |
# | Real CMB fit       | available in standard cosmology        | not performed here                                           | standard approach more complete |

# %%
# Full evidence is exported in /mnt/data/ecsm_ng9r_outputs
# Core equations are saved in ng9r_equations.md
# Out:
# NG9R evidence files created in /mnt/data/ecsm_ng9r_outputs
# Tests passed: 33/33
