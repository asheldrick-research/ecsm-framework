# %% [markdown]
# <a href="https://colab.research.google.com/github/asheldrick-research/ecsm-framework/blob/main/ECSM_NG7R_EXECUTED_Compact_Objects_Saturation_Transport_Trapping_and_Medium_Tidal_Susceptibility.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ECSM NG7R — Compact Objects, Saturation, Transport Trapping, and Medium Tidal Susceptibility
#
# This evidence notebook rebuilds compact-object-like behaviour without GR curvature.
#
# Main result:
# - compact states use finite saturated density, pressure, coherence and transport;
# - horizon-like behaviour is transport trapping `|u_r|=c_eff`;
# - tidal response is medium susceptibility, not metric Love number;
# - ringdown-like behaviour is shell stress modes;
# - no physical metric, Einstein equation, Schwarzschild/Kerr form, geodesic equation or singularity appears.
#
# Tests passed: 35/35.

# %% [markdown]
# ## Metadata
#
# ```json
# {
#   "notebook": "ECSM NG7R",
#   "title": "Compact Objects, Saturation, Transport Trapping, and Medium Tidal Susceptibility",
#   "physical_metric": false,
#   "curvature_action": false,
#   "einstein_equations": false,
#   "geodesic_equation": false,
#   "schwarzschild_or_kerr": false,
#   "metric_love_numbers": false,
#   "singularity_required": false,
#   "transport_boundaries_count": 2,
#   "transport_boundaries": [
#     0.8093987540701809,
#     0.9421925970303975
#   ],
#   "shell_radius": 1.0002750350070013,
#   "transport_ratio_max": 1.1173420395021296,
#   "medium_tidal_susceptibility": 0.39958144613410407,
#   "shell_mode_omega_min": 14.298661593310946,
#   "shell_mode_omega_max": 83.08295765274706,
#   "parameter_scan_points": 50000,
#   "parameter_scan_all_conditions": 50000,
#   "parameter_scan_conservative_transport_subset": 43368,
#   "main_result": "Compact-object-like states can be represented by finite saturation, transport trapping, shell stress modes, and medium tidal susceptibility without metric curvature.",
#   "claim_boundary": "Benchmark constitutive model only; full astrophysical fitting and strong-field rotation remain later work.",
#   "next_notebook": "NG8R - Unified Galaxies and Lensing from One Constitutive Response Kernel"
# }
# ```

# %% [markdown]
# ## Test summary
#
# | test                                                | passed   | detail   |
# |:----------------------------------------------------|:---------|:---------|
# | Profile table exported                              | True     |          |
# | Profile values finite                               | True     |          |
# | Density finite and saturated                        | True     |          |
# | Coherence floor positive                            | True     |          |
# | Pressure finite                                     | True     |          |
# | Central acceleration regular                        | True     |          |
# | Transport boundary exists                           | True     |          |
# | Transport ratio exceeds unity somewhere             | True     |          |
# | Regularity audit exported                           | True     |          |
# | All regularity conditions pass                      | True     |          |
# | Tidal profile exported                              | True     |          |
# | Tidal response finite                               | True     |          |
# | Tidal susceptibility positive                       | True     |          |
# | Tidal stiffness positive                            | True     |          |
# | Shell mode spectrum exported                        | True     |          |
# | Shell modes finite                                  | True     |          |
# | Shell frequencies positive                          | True     |          |
# | Parameter audit exported                            | True     |          |
# | Parameter audit has 50,000 rows                     | True     |          |
# | All parameter samples pass finite-saturation checks | True     |          |
# | Conservative transport subset nonempty              | True     |          |
# | Comparison table exported                           | True     |          |
# | Failure mode table exported                         | True     |          |
# | Claim ledger exported                               | True     |          |
# | Ontology audit exported                             | True     |          |
# | No forbidden geometric primitive present            | True     |          |
# | Metadata exported                                   | True     |          |
# | Six paper figures exported                          | True     |          |
# | No physical metric in metadata                      | True     |          |
# | No curvature action in metadata                     | True     |          |
# | No Einstein equations in metadata                   | True     |          |
# | No geodesic equation in metadata                    | True     |          |
# | No Schwarzschild/Kerr in metadata                   | True     |          |
# | No metric Love numbers in metadata                  | True     |          |
# | No singularity required in metadata                 | True     |          |

# %% [markdown]
# ## Non-geometric vs geometric comparison
#
# | aspect                         | previous_geometric_version     | non_geometric_NG7R                                             | assessment                                    |
# |:-------------------------------|:-------------------------------|:---------------------------------------------------------------|:----------------------------------------------|
# | Compact object core            | singularity or metric interior | finite saturated density and pressure                          | NG7R better                                   |
# | Horizon-like behaviour         | metric event horizon           | transport boundary |u|=c_eff                                   | NG7R better                                   |
# | Tidal response                 | metric Love number             | medium tidal susceptibility from stiffness                     | NG7R better                                   |
# | Ringdown                       | metric quasinormal modes       | shell stress modes and relaxation                              | NG7R better                                   |
# | Failure modes                  | coordinate/metric pathology    | finite response saturation, transport and stiffness conditions | NG7R better                                   |
# | Exact strong-field GR exterior | available                      | not yet rebuilt                                                | geometric more complete but not ECSM ontology |

# %%
# Full evidence is exported in /mnt/data/ecsm_ng7r_outputs
# Core equations are saved in ng7r_equations.md
# Out:
# NG7R evidence files created in /mnt/data/ecsm_ng7r_outputs
# Tests passed: 35/35
