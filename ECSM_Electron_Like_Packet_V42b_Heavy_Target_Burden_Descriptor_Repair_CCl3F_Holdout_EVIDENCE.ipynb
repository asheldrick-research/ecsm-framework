# %% [markdown]
# <a href="https://colab.research.google.com/github/asheldrick-research/ecsm-framework/blob/main/ECSM_Electron_Like_Packet_V42b_Heavy_Target_Burden_Descriptor_Repair_CCl3F_Holdout_EVIDENCE.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab">
# </a>

# %% [markdown]
# # ECSM V42b — Heavy Target-Burden Descriptor Repair for CCl3F Holdout
#
# This evidence notebook documents the V42b repair test. The descriptor family is trained/selected using methane, sevoflurane, and isoflurane only; CCl3F is withheld as the cold heavy-halogen target.

# %%
import pandas as pd, numpy as np, json, zipfile
from pathlib import Path
import matplotlib.pyplot as plt
print('V42b evidence notebook: rerun the full code from the GitHub script cell or inspect the embedded outputs below.')
# Out:
# V42b evidence notebook: rerun the full code from the GitHub script cell or inspect the embedded outputs below.
