# %% [markdown]
# <a href="https://colab.research.google.com/github/asheldrick-research/ecsm-framework/blob/main/ECSM_NG5R_v2_EXECUTED_Lorentz_Recovery_as_Moving_Matter_Packet_Closure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ECSM NG5R-v2 — Lorentz Recovery as Moving Matter-Packet Closure
#
# Tests passed: 9/9.

# %% [markdown]
# ## Metadata
# ```json
# {
#   "notebook": "ECSM NG5R-v2 addendum",
#   "title": "Lorentz Recovery as Moving Matter-Packet Closure",
#   "physical_metric": false,
#   "space_contraction": false,
#   "curvature_action": false,
#   "einstein_equations": false,
#   "geodesic_equation": false,
#   "main_result": "Length contraction is recovered as contraction of the moving matter response pattern, not contraction of space.",
#   "moving_solution": "X_v(x,t)=X_0(gamma(x-vt))",
#   "length_law": "L_v=L_0/gamma",
#   "loop_timing_law": "T_loop=gamma T_0",
#   "centre_phase_rate_law": "rate_v=rate_0/gamma",
#   "tests_passed": 9,
#   "tests_total": 9,
#   "velocity_scan_points": 50000,
#   "claim_boundary": "Benchmark finite-response packet derivation; full proof requires all ECSM matter sectors share the same closure operator."
# }
# ```

# %% [markdown]
# ## Test summary
# | test                                     | passed   |
# |:-----------------------------------------|:---------|
# | Contracted packet residuals near zero    | True     |
# | Wrong dragged packet fails at high speed | True     |
# | Profile width matches L0/gamma           | True     |
# | Loop timing gives gamma                  | True     |
# | Centre phase rate gives 1/gamma          | True     |
# | Velocity scan has 50,000 rows            | True     |
# | All velocity closure checks pass         | True     |
# | No forbidden geometric primitive present | True     |
# | Five paper figures exported              | True     |

# %% [markdown]
# ## Comparison
# | aspect             | previous_geometric_language   | non_geometric_ECSM_language                      | assessment                                    |
# |:-------------------|:------------------------------|:-------------------------------------------------|:----------------------------------------------|
# | Length contraction | space or spacetime geometry   | moving matter-response packet profile            | NG5R-v2 better                                |
# | Ruler              | object in geometric space     | stable matter response pattern                   | NG5R-v2 better                                |
# | Moving solution    | spacetime transform assumed   | finite-response equation selects squeezed packet | NG5R-v2 better                                |
# | Clock slowing      | time dilation from geometry   | finite response loop and centre phase rate       | NG5R-v2 better                                |
# | Local normality    | coordinate-frame postulate    | rods/clocks share moving matter state            | NG5R-v2 better                                |
# | Full SR formalism  | already complete              | bookkeeping after packet closure                 | geometric more complete but not ECSM ontology |

# %%
# Full evidence is exported in /mnt/data/ecsm_ng5r_v2_lorentz_outputs
# Out:
# NG5R-v2 evidence files created in /mnt/data/ecsm_ng5r_v2_lorentz_outputs
# Tests passed: 9/9
