# %% [markdown]
# <a href="https://colab.research.google.com/github/asheldrick-research/ecsm-framework/blob/main/ECSM_NG11R_EXECUTED_Electromagnetic_Constitutive_Closure_of_ECSM_Optical_Gravity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ECSM NG11R — Electromagnetic Constitutive Closure of ECSM Optical Gravity
#
# This notebook bridges the non-geometric gravity/lensing spine to the corrected causal electromagnetic response sector.
#
# Main result:
# - optical gravity is encoded through split electric/magnetic response;
# - n^2 = Z_E/Z_B;
# - a common scalar Z_c changes impedance but not propagation;
# - NG4/NG8/NG9 optical response is recovered as the weak limit of Z_E=Z_c exp(+Psi H), Z_B=Z_c exp(-Psi H);
# - domain-boundary gradients are retained in the differential split channel.
#
# Tests passed: 30/30.

# %% [markdown]
# ## Metadata
#
# ```json
# {
#   "notebook": "ECSM NG11R",
#   "title": "Electromagnetic Constitutive Closure of ECSM Optical Gravity",
#   "physical_metric": false,
#   "curvature_action": false,
#   "geodesic_equation": false,
#   "common_scalar_as_speed_law": false,
#   "split_constitutive_response": true,
#   "n_squared_equals_ZE_over_ZB": true,
#   "domain_boundary_gradients_retained": true,
#   "max_refractive_change_over_Zc_scan": 0.0,
#   "median_weak_relative_error": 0.0001361769665696518,
#   "far_field_deflection_relative_difference": 0.005572667388502813,
#   "boundary_omission_peak_residual": 0.31547417196308813,
#   "parameter_scan_points": 50000,
#   "parameter_scan_all_conditions": 30981,
#   "main_result": "ECSM optical gravity is recast as split electromagnetic constitutive response. A common scalar changes impedance, while differential ZE/ZB controls propagation.",
#   "claim_boundary": "Benchmark bridge only; real SPARC/KiDS/CMB data must be refit with split channels."
# }
# ```

# %% [markdown]
# ## Test summary
#
# | test                                       | passed   | detail   |
# |:-------------------------------------------|:---------|:---------|
# | Common scalar table exported               | True     |          |
# | Common scalar leaves n unchanged           | True     |          |
# | Common scalar changes impedance            | True     |          |
# | Split response summary exported            | True     |          |
# | Weak n approximately 1 plus Psi            | True     |          |
# | Deflection table exported                  | True     |          |
# | Deflection finite                          | True     |          |
# | Far field split deflection close to target | True     |          |
# | Boundary omission creates residual         | True     |          |
# | Boundary residual near domain scale        | True     |          |
# | Frequency table exported                   | True     |          |
# | Frequency response finite                  | True     |          |
# | Low frequency closes to exp Psi            | True     |          |
# | Passive low branch nonnegative Im n        | True     |          |
# | Parameter scan exported                    | True     |          |
# | Parameter scan has 50,000 rows             | True     |          |
# | More than 25,000 parameter samples pass    | True     |          |
# | Comparison table exported                  | True     |          |
# | Claim ledger exported                      | True     |          |
# | Failure mode table exported                | True     |          |
# | Ontology audit exported                    | True     |          |
# | No forbidden geometric primitive present   | True     |          |
# | Metadata exported                          | True     |          |
# | Six paper figures exported                 | True     |          |
# | Bridge addendum exported                   | True     |          |
# | No physical metric in metadata             | True     |          |
# | No geodesic equation in metadata           | True     |          |
# | Common scalar not used as speed law        | True     |          |
# | Split constitutive response used           | True     |          |
# | Boundary gradients retained                | True     |          |

# %% [markdown]
# ## Bridge comparison
#
# | aspect                    | before_bridge                    | NG11R_bridge                        | assessment      |
# |:--------------------------|:---------------------------------|:------------------------------------|:----------------|
# | NG4/NG8/NG9 optical index | scalar n_opt only                | n^2 = Z_E/Z_B                       | bridge complete |
# | Common scalar response    | could be confused with speed law | impedance/normalisation only        | corrected       |
# | Boundary lensing          | scalar boundary index term       | split-channel differential response | retained        |
# | Frequency dependence      | free propagation kernel          | causal oscillator response H(omega) | constrained     |
# | Empirical status          | synthetic benchmark              | requires SPARC/KiDS/CMB re-fit      | next work       |

# %%
# Full evidence is exported in /mnt/data/ecsm_ng11r_outputs
# Core bridge equations are saved in ng11r_equations.md
# Out:
# NG11R evidence files created in /mnt/data/ecsm_ng11r_outputs\nTests passed: 30/30\n
