# %% [markdown]
# <a href="https://colab.research.google.com/github/asheldrick-research/ecsm-framework/blob/main/ECSM_Electron_Like_Packet_V43_Heavy_Target_Burden_Descriptor_Repair_CCl3F_Holdout_EVIDENCE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ECSM V43 — Heavy Target-Burden Descriptor Repair for CCl3F Holdout
#
# This evidence notebook documents the V43 repair test. The descriptor family is trained/selected using methane, sevoflurane, and isoflurane only; CCl3F is withheld as the cold heavy-halogen target. The frozen ECSM packet remains unchanged.

# %%
import pandas as pd, numpy as np, json, zipfile
from pathlib import Path
import matplotlib.pyplot as plt
print('V43 evidence notebook: rerun the full code from the GitHub script cell or inspect the embedded outputs below.')
# Out:
# V43 evidence notebook: rerun the full code from the GitHub script cell or inspect the embedded outputs below.

# %% [markdown]
# ## Descriptor validation ranking

# %%
display(pd.DataFrame([{'descriptor_model': 'atom_count', 'target': 'training_targets_combined', 'phase': 'descriptor_selection', 'subset': 'validation_100_200_300', 'mean': 0.17786091218251537, 'median': 0.14607570073038717, 'max': 0.7327780793125651, 'n': 189}, {'descriptor_model': 'sqrt_atom_electron', 'target': 'training_targets_combined', 'phase': 'descriptor_selection', 'subset': 'validation_100_200_300', 'mean': 0.17816590032312934, 'median': 0.12903186596249083, 'max': 0.7379554385375754, 'n': 189}, {'descriptor_model': 'halogen_burden_plus_atom', 'target': 'training_targets_combined', 'phase': 'descriptor_selection', 'subset': 'validation_100_200_300', 'mean': 0.1782504840204663, 'median': 0.12945141499312587, 'max': 0.7377919337069858, 'n': 189}, {'descriptor_model': 'heavy_atom_count_plus1', 'target': 'training_targets_combined', 'phase': 'descriptor_selection', 'subset': 'validation_100_200_300', 'mean': 0.17860498898470487, 'median': 0.1291026141439266, 'max': 0.7376024521406811, 'n': 189}, {'descriptor_model': 'electron_count', 'target': 'training_targets_combined', 'phase': 'descriptor_selection', 'subset': 'validation_100_200_300', 'mean': 0.17868462355018458, 'median': 0.12650196726665533, 'max': 0.7365329292989109, 'n': 189}, {'descriptor_model': 'molar_mass', 'target': 'training_targets_combined', 'phase': 'descriptor_selection', 'subset': 'validation_100_200_300', 'mean': 0.17921058540327467, 'median': 0.126600745528778, 'max': 0.736208317039163, 'n': 189}, {'descriptor_model': 'sqrt_heavy_electron_plus1', 'target': 'training_targets_combined', 'phase': 'descriptor_selection', 'subset': 'validation_100_200_300', 'mean': 0.17925119510935525, 'median': 0.12735978934691147, 'max': 0.7372292451808204, 'n': 189}]))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>descriptor_model</th>
#       <th>target</th>
#       <th>phase</th>
#       <th>subset</th>
#       <th>mean</th>
#       <th>median</th>
#       <th>max</th>
#       <th>n</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>atom_count</td>
#       <td>training_targets_combined</td>
#       <td>descriptor_selection</td>
#       <td>validation_100_200_300</td>
#       <td>0.177861</td>
#       <td>0.146076</td>
#       <td>0.732778</td>
#       <td>189</td>
#     </tr>
#     <tr>
#       <td>sqrt_atom_electron</td>
#       <td>training_targets_combined</td>
#       <td>descriptor_selection</td>
#       <td>validation_100_200_300</td>
#       <td>0.178166</td>
#       <td>0.129032</td>
#       <td>0.737955</td>
#       <td>189</td>
#     </tr>
#     <tr>
#       <td>halogen_burden_plus_atom</td>
#       <td>training_targets_combined</td>
# ...

# %% [markdown]
# ## Selected descriptor summary

# %%
display(pd.DataFrame([{'target': 'methane', 'model': 'selected_atom_count', 'subset': 'validation_100_200_300', 'mean': 0.16619700297408324, 'median': 0.13415219154736177, 'max': 0.6405629344573224, 'n': 63}, {'target': 'sevoflurane', 'model': 'selected_atom_count', 'subset': 'validation_100_200_300', 'mean': 0.18692207860939744, 'median': 0.16380290032235004, 'max': 0.7327780793125651, 'n': 63}, {'target': 'isoflurane', 'model': 'selected_atom_count', 'subset': 'validation_100_200_300', 'mean': 0.1804636549640655, 'median': 0.11633171000458836, 'max': 0.6727712965222034, 'n': 63}, {'target': 'training_targets_combined', 'model': 'selected_atom_count', 'subset': 'validation_100_200_300', 'mean': 0.17786091218251537, 'median': 0.14607570073038717, 'max': 0.7327780793125651, 'n': 189}, {'target': 'ccl3f', 'model': 'selected_atom_count', 'subset': 'key_100_200', 'mean': 0.40609749958888824, 'median': 0.33956129542100993, 'max': 0.8941788476436286, 'n': 20}, {'target': 'ccl3f', 'model': 'selected_atom_count', 'subset': 'all_rows', 'mean': 0.4911939697948487, 'median': 0.396551564457129, 'max': 2.3026319724489155, 'n': 80}]))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>target</th>
#       <th>model</th>
#       <th>subset</th>
#       <th>mean</th>
#       <th>median</th>
#       <th>max</th>
#       <th>n</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>methane</td>
#       <td>selected_atom_count</td>
#       <td>validation_100_200_300</td>
#       <td>0.166197</td>
#       <td>0.134152</td>
#       <td>0.640563</td>
#       <td>63</td>
#     </tr>
#     <tr>
#       <td>sevoflurane</td>
#       <td>selected_atom_count</td>
#       <td>validation_100_200_300</td>
#       <td>0.186922</td>
#       <td>0.163803</td>
#       <td>0.732778</td>
#       <td>63</td>
#     </tr>
#     <tr>
#       <td>isoflurane</td>
#       <td>selected_atom_count</td>
#       <td>validation_100_200_300</td>
#       <td>0.180464</td>
#       <td>0.116332</td>
#       <td>0.672771</td>
#       <td>63</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ## CCl3F bare/V41/V43 comparison

# %%
display(pd.DataFrame([{'target': 'ccl3f', 'model': 'bare_ecsm', 'subset': 'all_rows', 'mean': 1.7843060877743, 'median': 0.8753978527920216, 'max': 10.475395853939501, 'n': 80}, {'target': 'ccl3f', 'model': 'bare_ecsm', 'subset': 'key_100_200', 'mean': 1.857075368822445, 'median': 0.8475865358776609, 'max': 7.930844025651342, 'n': 20}, {'target': 'ccl3f', 'model': 'frozen_v41_atom_count', 'subset': 'key_100_200', 'mean': 0.4092512584072642, 'median': 0.43256662038622773, 'max': 0.8928056223467798, 'n': 20}, {'target': 'ccl3f', 'model': 'frozen_v41_atom_count', 'subset': 'all_rows', 'mean': 0.5248688649671943, 'median': 0.5112447366184645, 'max': 2.332466919710291, 'n': 80}, {'target': 'ccl3f', 'model': 'selected_atom_count', 'subset': 'key_100_200', 'mean': 0.40609749958888824, 'median': 0.33956129542100993, 'max': 0.8941788476436286, 'n': 20}, {'target': 'ccl3f', 'model': 'selected_atom_count', 'subset': 'all_rows', 'mean': 0.4911939697948487, 'median': 0.396551564457129, 'max': 2.3026319724489155, 'n': 80}]))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>target</th>
#       <th>model</th>
#       <th>subset</th>
#       <th>mean</th>
#       <th>median</th>
#       <th>max</th>
#       <th>n</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ccl3f</td>
#       <td>bare_ecsm</td>
#       <td>all_rows</td>
#       <td>1.784306</td>
#       <td>0.875398</td>
#       <td>10.475396</td>
#       <td>80</td>
#     </tr>
#     <tr>
#       <td>ccl3f</td>
#       <td>bare_ecsm</td>
#       <td>key_100_200</td>
#       <td>1.857075</td>
#       <td>0.847587</td>
#       <td>7.930844</td>
#       <td>20</td>
#     </tr>
#     <tr>
#       <td>ccl3f</td>
#       <td>frozen_v41_atom_count</td>
#       <td>key_100_200</td>
#       <td>0.409251</td>
#       <td>0.432567</td>
#       <td>0.892806</td>
#       <td>20</td>
#     </tr>
#     <tr>
#       <td>ccl3f</td>
#       <td>frozen_v41_atom_count</td>
#       <td>all_rows</td>
# ...

# %% [markdown]
# ## Criteria and verdict

# %%
run_summary={'run_label': 'V43_heavy_target_burden_descriptor_repair_ccl3f_holdout', 'final_label': 'PASS_MODERATE_V43_DESCRIPTOR_REDUCES_CCL3F_FAILURE_NOT_STRICT', 'selected_descriptor': 'atom_count', 'selected_params': {'descriptor': 'atom_count', 'q_s': 1.1812653274551084, 'q_p': 9.805005186496508, 'B1': 0.9706201992939308, 'B2': -1.1947602717161867, 'gamma1': 0.5, 'gamma2': 1.0, 'train_log_mse': 0.11759108451006627, 'n_params': 6}, 'candidate_models': {'atom_count': {'descriptor': 'atom_count', 'q_s': 1.1812653274551084, 'q_p': 9.805005186496508, 'B1': 0.9706201992939308, 'B2': -1.1947602717161867, 'gamma1': 0.5, 'gamma2': 1.0, 'train_log_mse': 0.11759108451006627, 'n_params': 6}, 'electron_count': {'descriptor': 'electron_count', 'q_s': 9.805005186496508, 'q_p': 1.1812653274551084, 'B1': 1.1719604178428644, 'B2': 4.637146338645966, 'gamma1': 0.0, 'gamma2': 0.5, 'train_log_mse': 0.11809612782717173, 'n_params': 6}, 'heavy_atom_count_plus1': {'descriptor': 'heavy_atom_count_plus1', 'q_s': 9.805005186496508, 'q_p': 1.80371339670776, 'B1': 1.142481324463003, 'B2': 2.894974671702901, 'gamma1': 0.0, 'gamma2': 0.5, 'train_log_mse': 0.11784641422628656, 'n_params': 6}, 'molar_mass': {'descriptor': 'molar_mass', 'q_s': 9.805005186496508, 'q_p': 1.1812653274551084, 'B1': 1.1764739801468798, 'B2': 4.122865068839905, 'gamma1': 0.0, 'gamma2': 0.5, 'train_log_mse': 0.11830589927261247, 'n_params': 6}, 'sqrt_atom_electron': {'descriptor': 'sqrt_atom_electron', 'q_s': 9.805005186496508, 'q_p': 1.80371339670776, 'B1': 1.1388715909770561, 'B2': 3.1418267272089615, 'gamma1': 0.0, 'gamma2': 0.5, 'train_log_mse': 0.11787853797103225, 'n_params': 6}, 'sqrt_heavy_electron_plus1': {'descriptor': 'sqrt_heavy_electron_plus1', 'q_s': 9.805005186496508, 'q_p': 1.80371339670776, 'B1': 1.147479124480952, 'B2': 2.585388795851445, 'gamma1': 0.0, 'gamma2': 0.5, 'train_log_mse': 0.1179224653648205, 'n_params': 6}, 'halogen_burden_plus_atom': {'descriptor': 'halogen_burden_plus_atom', 'q_s': 9.805005186496508, 'q_p': 1.80371339670776, 'B1': 1.1399285977238636, 'B2': 3.073396273936822, 'gamma1': 0.0, 'gamma2': 0.5, 'train_log_mse': 0.11786167500587769, 'n_params': 6}}, 'validation_ranking': [{'descriptor_model': 'atom_count', 'target': 'training_targets_combined', 'phase': 'descriptor_selection', 'subset': 'validation_100_200_300', 'mean': 0.17786091218251537, 'median': 0.14607570073038717, 'max': 0.7327780793125651, 'n': 189}, {'descriptor_model': 'sqrt_atom_electron', 'target': 'training_targets_combined', 'phase': 'descriptor_selection', 'subset': 'validation_100_200_300', 'mean': 0.17816590032312934, 'median': 0.12903186596249083, 'max': 0.7379554385375754, 'n': 189}, {'descriptor_model': 'halogen_burden_plus_atom', 'target': 'training_targets_combined', 'phase': 'descriptor_selection', 'subset': 'validation_100_200_300', 'mean': 0.1782504840204663, 'median': 0.12945141499312587, 'max': 0.7377919337069858, 'n': 189}, {'descriptor_model': 'heavy_atom_count_plus1', 'target': 'training_targets_combined', 'phase': 'descriptor_selection', 'subset': 'validation_100_200_300', 'mean': 0.17860498898470487, 'median': 0.1291026141439266, 'max': 0.7376024521406811, 'n': 189}, {'descriptor_model': 'electron_count', 'target': 'training_targets_combined', 'phase': 'descriptor_selection', 'subset': 'validation_100_200_300', 'mean': 0.17868462355018458, 'median': 0.12650196726665533, 'max': 0.7365329292989109, 'n': 189}, {'descriptor_model': 'molar_mass', 'target': 'training_targets_combined', 'phase': 'descriptor_selection', 'subset': 'validation_100_200_300', 'mean': 0.17921058540327467, 'median': 0.126600745528778, 'max': 0.736208317039163, 'n': 189}, {'descriptor_model': 'sqrt_heavy_electron_plus1', 'target': 'training_targets_combined', 'phase': 'descriptor_selection', 'subset': 'validation_100_200_300', 'mean': 0.17925119510935525, 'median': 0.12735978934691147, 'max': 0.7372292451808204, 'n': 189}], 'selected_summary': [{'target': 'methane', 'model': 'selected_atom_count', 'subset': 'validation_100_200_300', 'mean': 0.16619700297408324, 'median': 0.13415219154736177, 'max': 0.6405629344573224, 'n': 63}, {'target': 'sevoflurane', 'model': 'selected_atom_count', 'subset': 'validation_100_200_300', 'mean': 0.18692207860939744, 'median': 0.16380290032235004, 'max': 0.7327780793125651, 'n': 63}, {'target': 'isoflurane', 'model': 'selected_atom_count', 'subset': 'validation_100_200_300', 'mean': 0.1804636549640655, 'median': 0.11633171000458836, 'max': 0.6727712965222034, 'n': 63}, {'target': 'training_targets_combined', 'model': 'selected_atom_count', 'subset': 'validation_100_200_300', 'mean': 0.17786091218251537, 'median': 0.14607570073038717, 'max': 0.7327780793125651, 'n': 189}, {'target': 'ccl3f', 'model': 'selected_atom_count', 'subset': 'key_100_200', 'mean': 0.40609749958888824, 'median': 0.33956129542100993, 'max': 0.8941788476436286, 'n': 20}, {'target': 'ccl3f', 'model': 'selected_atom_count', 'subset': 'all_rows', 'mean': 0.4911939697948487, 'median': 0.396551564457129, 'max': 2.3026319724489155, 'n': 80}], 'bare_summary': [{'target': 'methane', 'model': 'bare_ecsm', 'subset': 'all_rows', 'mean': 0.8680585360803282, 'median': 0.4887204472476113, 'max': 5.659679606523363, 'n': 126}, {'target': 'methane', 'model': 'bare_ecsm', 'subset': 'validation_100_200_300', 'mean': 0.8704389668015856, 'median': 0.5219751223357997, 'max': 5.19470133560979, 'n': 63}, {'target': 'sevoflurane', 'model': 'bare_ecsm', 'subset': 'all_rows', 'mean': 1.2552767295545462, 'median': 0.5984543134324205, 'max': 9.728258823007211, 'n': 126}, {'target': 'sevoflurane', 'model': 'bare_ecsm', 'subset': 'validation_100_200_300', 'mean': 1.1724543799908071, 'median': 0.5835588322812202, 'max': 7.103760237778845, 'n': 63}, {'target': 'isoflurane', 'model': 'bare_ecsm', 'subset': 'all_rows', 'mean': 1.0886060744808048, 'median': 0.6666884221474308, 'max': 8.045915935009972, 'n': 126}, {'target': 'isoflurane', 'model': 'bare_ecsm', 'subset': 'validation_100_200_300', 'mean': 0.9768303242411737, 'median': 0.6282139126656726, 'max': 4.420527827587325, 'n': 63}, {'target': 'ccl3f', 'model': 'bare_ecsm', 'subset': 'all_rows', 'mean': 1.7843060877743, 'median': 0.8753978527920216, 'max': 10.475395853939501, 'n': 80}, {'target': 'ccl3f', 'model': 'bare_ecsm', 'subset': 'key_100_200', 'mean': 1.857075368822445, 'median': 0.8475865358776609, 'max': 7.930844025651342, 'n': 20}], 'v41_ccl3f_summary': [{'target': 'ccl3f', 'model': 'frozen_v41_atom_count', 'subset': 'key_100_200', 'mean': 0.4092512584072642, 'median': 0.43256662038622773, 'max': 0.8928056223467798, 'n': 20}, {'target': 'ccl3f', 'model': 'frozen_v41_atom_count', 'subset': 'all_rows', 'mean': 0.5248688649671943, 'median': 0.5112447366184645, 'max': 2.332466919710291, 'n': 80}], 'criteria': [{'criterion': 'CCl3F withheld from descriptor fitting', 'value': 1, 'pass': True}, {'criterion': 'descriptor selected only on methane/sevoflurane/isoflurane validation', 'value': 'atom_count', 'pass': True}, {'criterion': 'training-target validation mean <= 0.25', 'value': 0.17786091218251537, 'pass': True}, {'criterion': 'CCl3F key mean <= 0.25', 'value': 0.40609749958888824, 'pass': False}, {'criterion': 'CCl3F improved over V41 atom-count', 'value': 0.9922938323252815, 'pass': True}, {'criterion': 'CCl3F improved over bare by >50 percent', 'value': 0.21867583104416008, 'pass': True}, {'criterion': 'no ECSM packet retuning', 'value': 1, 'pass': True}], 'claim_boundary': 'V43 trains/chooses descriptors only on methane, sevoflurane, and isoflurane, then cold-tests CCl3F. It repairs the CCl3F failure only if the held-out CCl3F residual improves without using CCl3F in descriptor selection.'}
print(json.dumps(run_summary,indent=2))
display(pd.DataFrame([{'criterion': 'CCl3F withheld from descriptor fitting', 'value': 1, 'pass': True}, {'criterion': 'descriptor selected only on methane/sevoflurane/isoflurane validation', 'value': 'atom_count', 'pass': True}, {'criterion': 'training-target validation mean <= 0.25', 'value': 0.17786091218251537, 'pass': True}, {'criterion': 'CCl3F key mean <= 0.25', 'value': 0.40609749958888824, 'pass': False}, {'criterion': 'CCl3F improved over V41 atom-count', 'value': 0.9922938323252815, 'pass': True}, {'criterion': 'CCl3F improved over bare by >50 percent', 'value': 0.21867583104416008, 'pass': True}, {'criterion': 'no ECSM packet retuning', 'value': 1, 'pass': True}]))
# Out:
# {
#   "run_label": "V43_heavy_target_burden_descriptor_repair_ccl3f_holdout",
#   "final_label": "PASS_MODERATE_V43_DESCRIPTOR_REDUCES_CCL3F_FAILURE_NOT_STRICT",
#   "selected_descriptor": "atom_count",
#   "selected_params": {
#     "descriptor": "atom_count",
#     "q_s": 1.1812653274551084,
#     "q_p": 9.805005186496508,
#     "B1": 0.9706201992939308,
#     "B2": -1.1947602717161867,
#     "gamma1": 0.5,
#     "gamma2": 1.0,
#     "train_log_mse": 0.11759108451006627,
#     "n_params": 6
#   },
#   "candidate_models": {
#     "atom_count": {
#       "descriptor": "atom_count",
#       "q_s": 1.1812653274551084,
#       "q_p": 9.805005186496508,
#       "B1": 0.9706201992939308,
#       "B2": -1.1947602717161867,
#       "gamma1": 0.5,
#       "gamma2": 1.0,
#       "train_log_mse": 0.11759108451006627,
#       "n_params": 6
#     },
#     "electron_count": {
#       "descriptor": "electron_count",
#       "q_s": 9.805005186496508,
#       "q_p": 1.1812653274551084,
# ...

# %% [markdown]
# ## Figures

# %%
# Embedded paper figures generated by the V43 run

# %% [markdown]
# ## Export note

# %%
# The output pack contains CSVs, figures, and run_summary_v43.json.
print('Exported pack: ecsm_v43_heavy_target_burden_descriptor_evidence_pack.zip')
# Out:
# Exported pack: ecsm_v43_heavy_target_burden_descriptor_evidence_pack.zip
