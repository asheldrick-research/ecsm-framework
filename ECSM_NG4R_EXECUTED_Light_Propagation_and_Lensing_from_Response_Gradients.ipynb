# %% [markdown]
# <a href="https://colab.research.google.com/github/asheldrick-research/ecsm-framework/blob/main/ECSM_NG4R_EXECUTED_Light_Propagation_and_Lensing_from_Response_Gradients.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ECSM NG4R — Light Propagation and Lensing from Response Gradients
#
# This evidence notebook rebuilds ECSM optical propagation without physical spacetime curvature.
#
# Main result:
# - weak deflection is derived from `alpha(b)=∫ partial_b n_opt dz`;
# - source-burden deflection recovers the `1/b` scaling;
# - the standard weak coefficient requires `eta_B=2`;
# - domain-boundary gradients produce a separate lensing shoulder/ring contribution;
# - Shapiro-like delay is optical travel-time excess;
# - no physical metric, curvature action, Einstein equation, or geodesic equation appears.
#
# Tests passed: 40/40.

# %% [markdown]
# ## Benchmark metadata
#
# ```json
# {
#   "notebook": "ECSM NG4R",
#   "title": "Light Propagation and Lensing from Dispersion, Impedance, Coherence, and Domain-Boundary Gradients",
#   "physical_metric": false,
#   "curvature_action": false,
#   "einstein_equations": false,
#   "geodesic_equation": false,
#   "uses_hamiltonian_ray_transport": true,
#   "eta_B_benchmark": 2.0,
#   "eta_B_required_for_standard_weak_deflection": 2.0,
#   "far_burden_ratio_median": 0.9971829151422024,
#   "far_burden_ratio_max_abs_error": 0.0049628098201202064,
#   "boundary_peak_impact": 6.025471698113209,
#   "delay_log_slope_relative_error": 0.019366069064743873,
#   "raytrace_max_abs_relative_difference": 0.06283216611382257,
#   "parameter_points": 50000,
#   "parameter_points_passing": 50000,
#   "main_result": "Weak light deflection and optical delay arise from medium dispersion gradients without physical curvature or null geodesics.",
#   "claim_boundary": "The microphysical value of eta_B and full PPN closure remain for NG5R.",
#   "next_notebook": "NG5R - Coherent Relativistic Recovery, PPN-Equivalent Closure, and Stress-Wave Propagation"
# }
# ```

# %% [markdown]
# ## Test summary
#
# | test                                                | passed   | detail   |
# |:----------------------------------------------------|:---------|:---------|
# | Benchmark parameters exported                       | True     |          |
# | Inherited m_I positive                              | True     |          |
# | Inherited G_eff positive                            | True     |          |
# | Response speed positive                             | True     |          |
# | Optical profile exported                            | True     |          |
# | Optical index positive                              | True     |          |
# | Coherence positive                                  | True     |          |
# | Boundary gradient nonzero                           | True     |          |
# | Optical profiles finite                             | True     |          |
# | Lensing scan exported                               | True     |          |
# | Lensing scan finite                                 | True     |          |
# | Far burden deflection median closes                 | True     |          |
# | Far burden deflection max error controlled          | True     |          |
# | Boundary peak near domain radius                    | True     |          |
# | Boundary deflection nonzero                         | True     |          |
# | Signal delay scan exported                          | True     |          |
# | Signal delay finite                                 | True     |          |
# | Signal delay positive                               | True     |          |
# | Delay log slope recovered within 3 percent          | True     |          |
# | Raytrace table exported                             | True     |          |
# | Raytrace finite                                     | True     |          |
# | Raytrace agrees with weak-integral within 8 percent | True     |          |
# | Ray paths exported                                  | True     |          |
# | Eta scan exported                                   | True     |          |
# | Eta_B=2 gives standard coefficient                  | True     |          |
# | Parameter audit exported                            | True     |          |
# | Parameter audit contains 50,000 points              | True     |          |
# | All sampled points pass mathematical conditions     | True     |          |
# | Comparison table exported                           | True     |          |
# | Failure mode table exported                         | True     |          |
# | Claim ledger exported                               | True     |          |
# | Ontology audit exported                             | True     |          |
# | No forbidden geometric primitive present            | True     |          |
# | Metadata exported                                   | True     |          |
# | Eight paper figures exported                        | True     |          |
# | No physical metric in metadata                      | True     |          |
# | No curvature action in metadata                     | True     |          |
# | No Einstein equations in metadata                   | True     |          |
# | No geodesic equation in metadata                    | True     |          |
# | Hamiltonian ray transport recorded                  | True     |          |

# %% [markdown]
# ## Non-geometric vs geometric comparison
#
# | aspect                      | previous_geometric_version         | non_geometric_NG4R                                   | assessment                                |
# |:----------------------------|:-----------------------------------|:-----------------------------------------------------|:------------------------------------------|
# | Light propagation mechanism | null geodesics of effective metric | Hamiltonian transport from local dispersion          | NG4R better                               |
# | Lensing source              | curvature / metric potential       | burden, coherence, impedance, and boundary gradients | NG4R better                               |
# | Weak 1/b deflection         | imported from GR metric            | derived from refractive integral                     | NG4R better                               |
# | GR coefficient              | hidden in metric closure           | explicit eta_B=2 optical closure condition           | NG4R better                               |
# | Domain boundaries           | usually absent or secondary        | explicit lensing shoulder/ring contribution          | NG4R better                               |
# | Signal delay                | geometric Shapiro delay            | optical travel-time excess                           | NG4R better                               |
# | Microphysical coefficients  | not required once metric assumed   | still need derivation                                | geometric more complete but less faithful |
# | Full PPN closure            | available by metric construction   | not yet derived                                      | not yet better                            |

# %%
# Key equations:
# omega = c_R |k| / n_opt(x)
# n_opt = 1 + eta_B B + eta_chi L_chi |grad chi| + ...
# alpha(b) = integral partial_b n_opt dz
# Delta T = integral [n_opt - 1] dz / c_R
# Full computed evidence is exported in ecsm_ng4r_outputs.
# Out:
# NG4R evidence files created in /mnt/data/ecsm_ng4r_outputs\nTests passed: 40/40\n
